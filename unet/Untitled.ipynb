# %%
from skimage import io
import numpy as np
import os 
import matplotlib.pyplot as plt
% matplotlib inline

# %%
data_path =os.path.join(os.getcwd(),'far/train') 
img = io.imread(os.path.join(data_path,'0_pred.png'),as_gray = True)
img_m = img * 255
io.imshow(img)
label = io.imread(os.path.join(data_path,'image_1.png'),as_gray = True)
#io.imshow(label)
# Out:
# D:\anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:77: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %%
data_path =os.path.join(os.getcwd(),'far/train') 
img = io.imread(os.path.join(data_path,'image/image_1.png'),as_gray = True)
mean = np.mean(img)
std = np.std(img)
img_m = (img - mean)/ std
plt.figure(1)
plt.subplot(211)
io.imshow(img,)
plt.subplot(212)
io.imshow(img_m)
